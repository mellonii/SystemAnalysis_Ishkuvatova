# %% [markdown]
# Задание: написать алгоритм который cчитает энтропию матрицы отношений (оценка сложности структуры). Это число определяет количество бит, которое необходимо, чтобы задать эту систему (с заданным числом отношений)

# %% [markdown]
# ![photo_2024-10-06_21-55-50.jpg](attachment:photo_2024-10-06_21-55-50.jpg)

# %% [markdown]
# Из прошлого задания возьмем матрицу отношений:

# %%
import math

matrix = [[0, 1, 0, 6, 0], [1, 2, 0, 4, 0], [1, 2, 1, 0, 1], [1, 2, 1, 0, 1], [1, 0, 2, 0, 1], [1, 0, 2, 0, 1], [1, 0, 2, 0, 1], [1, 0, 2, 0, 1]]
gamma = 8 # количество вершин
p = 1/(gamma - 1)

H = 0

for tmp in matrix:
    for x in tmp:
        if x != 0:
            H -= p*x*math.log2(p*x)

print(H)
# Out:
# 10.683488839711028
